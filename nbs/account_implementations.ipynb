# %%
import pandas as pd
import json

# %%
data_path = '/Users/nvtrang/code/starknet/open-sourcooor/data/nights-watch/nbs/data_sample/3981.json'
with open(data_path) as data_file:
    dict_data = json.load(data_file)

L = dict_data['data']['acc_impls']
df = pd.DataFrame(L)
df
# Out:
#                                                     id  \
# 0    0x100e70e79c2b59bfa540eb77d2d82d3d832f5f4ae2f5...
# 1    0x10425cb6faafcf904b0353483538ee9414f23976e0cc...
# 2    0x105f78e28279df781da3a0cfd7a8ae56f7d0a4c9566e...
# 3    0x1063857b5f57cb1310483e18438c264a61b7ba5240e5...
# 4    0x106c57177ada5839b94a430417b826ea31f31281d9c8...
# ..                                                 ...
# 995  0x47763a36941414d7cccc0dd428aeba571ca7adac5eb6...
# 996  0x477e264af628ee8eb079c0fe233b3c96abc2816a27d0...
# 997  0x47806dc6fd9ae8641be130f751786644cec63a9f4e63...
# 998  0x479392d3f1c67d6d7e374d986b115c46ccf10b6569f0...
# 999  0x479e07a4ee9c782ecd5c979d9f9f9df179e60d280246...
#
#                                                tx_hash  created_at  \
# 0    0x100e70e79c2b59bfa540eb77d2d82d3d832f5f4ae2f5...  1652156603
# 1    0x10425cb6faafcf904b0353483538ee9414f23976e0cc...  1651304763
# 2    0x105f78e28279df781da3a0cfd7a8ae56f7d0a4c9566e...  1652178617
# ...

# %%
df['implementation'].value_counts()
# Out:
# 0x1bd7ca87f139693e6681be2042194cf631c4e8d77027bf0ea9e6d55fc6018ac    977
# 0x69577e6756a99b584b5d1ce8e60650ae33b6e2b13541783458268f07da6b38a     23
# Name: implementation, dtype: int64
